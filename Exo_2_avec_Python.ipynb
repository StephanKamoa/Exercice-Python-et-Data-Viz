# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
diamonds = pd.read_csv('C:/Users/KAMOA/Downloads/Compressed/diamonds.csv')

# %%
diamonds.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
#  Un diagramme de disperssion de la colonne prix par rapport à la colonne carat

# %%
sns.scatterplot(x="carat", y="price", data=diamonds)
plt.xlabel("carat")
plt.ylabel("price")
plt.show()

# %% [markdown]
# ### Utilisation du paramètre alpha et le paramètre edgecolor pour traiter le problème de

# %%
sns.scatterplot(x="carat", y="price", data=diamonds, alpha=0.1, edgecolor='blue')
plt.xlabel("carat")
plt.ylabel("price")
plt.show()

# %%
plt.figure(figsize=(10, 8))

sns.scatterplot(x="carat", y="price", data=diamonds, alpha=0.5, edgecolor='blue')
plt.xlabel("carat")
plt.ylabel("price")
plt.show()

# %%
sns.histplot(data=diamonds, x="price")
plt.xlabel('price')
plt.show()

# %%
sns.countplot(x="cut", data=diamonds)
plt.xlabel("cut")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x="cut", y="price", data=diamonds)
plt.xlabel("cut")
plt.ylabel("price")
plt.show()

# %%
array = ['Fair', 'Ideal', 'Good', 'Very Good', 'Premium']
plt.figure(figsize=(10, 8))
sns.boxplot(x="cut", y="price", data=diamonds, palette="pastel", order=array)
plt.xlabel("cut")
plt.ylabel("price")
plt.show()
